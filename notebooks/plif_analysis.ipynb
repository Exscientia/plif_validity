# %%
import sys
import warnings
from collections import defaultdict

import dill as pkl
import pandas as pd
from tqdm.autonotebook import tqdm

sys.path.append("..")
from plif_utils.analysis import get_plifs, get_plif_recovery_rates
from plif_utils.file_prep import get_files
from plif_utils.settings import DATA_DIR, settings
from plif_utils.system_prep import SystemPrep

warnings.filterwarnings("ignore", module="Bio")
# Out:
# /var/folders/r5/pdy334cn3pq3w3pd5_hsl4z80000gq/T/ipykernel_6061/3155140701.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# /Users/cbouysset/miniforge3/envs/plif-recovery/lib/python3.11/site-packages/Bio/pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(

# %%
system_prep = SystemPrep()

posebuster_targets = [
    line.strip()
    for line in (DATA_DIR / "posebusters_ccd_ids.txt").read_text().split("\n")
]

# %% [markdown]
# ## Collect The PLIFs

# %%
plif_dict = {}

# %%
methods_with_progress = tqdm(["xtal", "fred", "hybrid", "gold"], position=0)

for method in methods_with_progress:
    plif_dict[method] = get_plifs(posebuster_targets, method, system_prep)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for xtal::7SUC_COM
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for xtal::8F4J_PHO
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for fred::8F4J_PHO
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for hybrid::7SUC_COM
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for hybrid::8F4J_PHO
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for gold::8F4J_PHO
#   warnings.warn(f"Could not prepare system for {method}::{target}")

# %%
targets_with_progress = tqdm(posebuster_targets)
plif_dict["umol"] = get_plifs(targets_with_progress, "umol", system_prep)
# Out:
#   0%|          | 0/308 [00:00<?, ?it/s]
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7B2C_TP7
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7CNQ_G8X
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7D6O_MTE
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7FRX_O88
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7KB1_WBJ
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7MFP_Z7P
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# [14:10:26] Skipping unrecognized collection type at line 120: MDLV30/STEABS ATOMS=(0)
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7NXO_UU8
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7OP9_06K
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# [14:11:36] Skipping unrecognized collection type at line 79: MDLV30/STEABS ATOMS=(0)
# [14:11:50] Skipping unrecognized collection type at line 58: MDLV30/STEABS ATOMS=(0)
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7P2I_MFU
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7R6J_2I7
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7SUC_COM
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7TB0_UD1
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7XRL_FWK
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# [14:24:42] Skipping unrecognized collection type at line 53: MDLV30/STEABS ATOMS=(0)
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7Z2O_IAJ
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::7ZDY_6MJ
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::8AQL_PLG
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# [14:27:44] Skipping unrecognized collection type at line 109: MDLV30/STEABS ATOMS=(0)
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for umol::8F4J_PHO
#   warnings.warn(f"Could not prepare system for {method}::{target}")

# %%
targets_with_progress = tqdm(posebuster_targets)
plif_dict["diffdock"] = get_plifs(targets_with_progress, "diffdock", system_prep)
# Out:
#   0%|          | 0/308 [00:00<?, ?it/s]
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:246: UserWarning: Unable to determine bond orders for MHS291.D, stripping it.
#   warnings.warn(
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:246: UserWarning: Unable to determine bond orders for AGM305.A, stripping it.
#   warnings.warn(
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:246: UserWarning: Unable to determine bond orders for GL3490.A, stripping it.
#   warnings.warn(
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:246: UserWarning: Unable to determine bond orders for HIC491.A, stripping it.
#   warnings.warn(
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for diffdock::7D6O_MTE
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for diffdock::7FRX_O88
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:246: UserWarning: Unable to determine bond orders for KCX73.B, stripping it.
#   warnings.warn(
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:246: UserWarning: Unable to determine bond orders for UDP611.B, stripping it.
#   warnings.warn(
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for diffdock::7M31_TDR
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:265: UserWarning: Invalid bond orders detected for LLP680.A: SMILES='[H]N[C@@]([H])(C=O)C([H])([H])C([H])([H])C([H])([H])C([H])([H])[N+]([H])([H])[C-]([H])c1c(O[H])c(C([H])([H])[H])nc([H])c1C([H])([H])OP(=O)([O-])[O-]', stripping it.
#   warnings.warn(f"{msg}, stripping it.")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:265: UserWarning: Invalid bond orders detected for MSE73.B: SMILES='[H]NC([H])(C=O)C([H])([H])C([H])([H])[Se]#[C+2]([H])([H])[H]', stripping it.
#   warnings.warn(f"{msg}, stripping it.")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:265: UserWarning: Invalid bond orders detected for MSE128.A: SMILES='[H]NC([H])(C=O)C([H])([H])C([H])([H])[Se]#[C+2]([H])([H])[H]', stripping it.
#   warnings.warn(f"{msg}, stripping it.")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for diffdock::7SUC_COM
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:265: UserWarning: Invalid bond orders detected for FFQ502.D: SMILES='[H]O[C@]([H])([C-]([H])C([H])([H])[H])P(=O)([O-])[O-]', stripping it.
#   warnings.warn(f"{msg}, stripping it.")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:246: UserWarning: Unable to determine bond orders for UNK288.A, stripping it.
#   warnings.warn(
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:75: UserWarning: Could not prepare system for diffdock::8F4J_PHO
#   warnings.warn(f"Could not prepare system for {method}::{target}")

# %%
targets_with_progress = tqdm(posebuster_targets)
plif_dict["rfaa"] = get_plifs(targets_with_progress, "rfaa", system_prep)
# Out:
#   0%|          | 0/308 [00:00<?, ?it/s]
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::5SAK_ZRY
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::6XHT_V2V
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::6Z14_Q4Z
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:100: UserWarning: Non-aromatic histidine HIS85.A detected, fixing.
#   warnings.warn(f"Non-aromatic histidine {resid!s} detected, fixing.")
# [11:11:45] Can't kekulize mol.  Unkekulized atoms: 429 432 434
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7AFX_R9K
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7B2C_TP7
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:100: UserWarning: Non-aromatic histidine HIS296.A detected, fixing.
#   warnings.warn(f"Non-aromatic histidine {resid!s} detected, fixing.")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:100: UserWarning: Non-aromatic histidine HIS297.A detected, fixing.
#   warnings.warn(f"Non-aromatic histidine {resid!s} detected, fixing.")
# [11:12:25] Can't kekulize mol.  Unkekulized atoms: 119 122 124
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7BJJ_TVW
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7BKA_4JC
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7CNQ_G8X
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7D5C_GV6
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7D6O_MTE
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7DKT_GLF
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7FRX_O88
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7K0V_VQP
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7M31_TDR
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7NU0_DCL
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7OP9_06K
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7P4C_5OV
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7PIH_7QW
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:100: UserWarning: Non-aromatic histidine HIS41.A detected, fixing.
#   warnings.warn(f"Non-aromatic histidine {resid!s} detected, fixing.")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:100: UserWarning: Non-aromatic histidine HIS167.A detected, fixing.
#   warnings.warn(f"Non-aromatic histidine {resid!s} detected, fixing.")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7Q5I_I0F
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7QFM_AY3
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7QHL_D5P
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7SCW_GSP
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7SFO_98L
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7SUC_COM
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# [11:39:06] Can't kekulize mol.  Unkekulized atoms: 33 34 35 37 39
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7TH4_FFO
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# [11:44:42] Can't kekulize mol.  Unkekulized atoms: 12 19 20 21 22
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7UYB_OK0
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7WDT_NGS
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7WJB_BGC
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7WQQ_5Z6
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7X5N_5M5
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7XRL_FWK
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:100: UserWarning: Non-aromatic histidine HIS96.A detected, fixing.
#   warnings.warn(f"Non-aromatic histidine {resid!s} detected, fixing.")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:100: UserWarning: Non-aromatic histidine HIS151.A detected, fixing.
#   warnings.warn(f"Non-aromatic histidine {resid!s} detected, fixing.")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::7ZDY_6MJ
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::8AQL_PLG
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::8D5D_5DK
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:100: UserWarning: Non-aromatic histidine HIS188.A detected, fixing.
#   warnings.warn(f"Non-aromatic histidine {resid!s} detected, fixing.")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::8EXL_799
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::8EYE_X4I
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::8F4J_PHO
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/analysis.py:76: UserWarning: Could not prepare system for rfaa::8G0V_YHT
#   warnings.warn(f"Could not prepare system for {method}::{target}")
# /Users/cbouysset/projects/plif-recovery/notebooks/../plif_utils/system_prep.py:100: UserWarning: Non-aromatic histidine HIS83.A detected, fixing.
#   warnings.warn(f"Non-aromatic histidine {resid!s} detected, fixing.")

# %%
# number of failures per method
all_targets = set(posebuster_targets)
missing = {m: all_targets.difference(xs) for m, xs in plif_dict.items()}
{k: len(v) for k,v in missing.items()}
# Out:
# {'xtal': 2,
#  'fred': 1,
#  'hybrid': 2,
#  'gold': 1,
#  'umol': 17,
#  'diffdock': 5,
#  'rfaa': 38}

# %%
# details on failures
from pprint import pprint
pprint(missing, compact=True, sort_dicts=False)
# Out:
# {'xtal': {'7SUC_COM', '8F4J_PHO'},
#  'fred': {'8F4J_PHO'},
#  'hybrid': {'7SUC_COM', '8F4J_PHO'},
#  'gold': {'8F4J_PHO'},
#  'umol': {'7B2C_TP7', '7CNQ_G8X', '7D6O_MTE', '7FRX_O88', '7KB1_WBJ',
#           '7MFP_Z7P', '7NXO_UU8', '7OP9_06K', '7P2I_MFU', '7R6J_2I7',
#           '7SUC_COM', '7TB0_UD1', '7XRL_FWK', '7Z2O_IAJ', '7ZDY_6MJ',
#           '8AQL_PLG', '8F4J_PHO'},
#  'diffdock': {'7D6O_MTE', '7SUC_COM', '7FRX_O88', '8F4J_PHO', '7M31_TDR'},
#  'rfaa': {'5SAK_ZRY', '6XHT_V2V', '6Z14_Q4Z', '7AFX_R9K', '7B2C_TP7',
#           '7BJJ_TVW', '7BKA_4JC', '7CNQ_G8X', '7D5C_GV6', '7D6O_MTE',
#           '7DKT_GLF', '7FRX_O88', '7K0V_VQP', '7M31_TDR', '7NU0_DCL',
#           '7OP9_06K', '7P4C_5OV', '7PIH_7QW', '7Q5I_I0F', '7QFM_AY3',
#           '7QHL_D5P', '7SCW_GSP', '7SFO_98L', '7SUC_COM', '7TH4_FFO',
#           '7UYB_OK0', '7WDT_NGS', '7WJB_BGC', '7WQQ_5Z6', '7X5N_5M5',
#           '7XRL_FWK', '7ZDY_6MJ', '8AQL_PLG', '8D5D_5DK', '8EXL_799',
#           '8EYE_X4I', '8F4J_PHO', '8G0V_YHT'}}

# %%
len(posebuster_targets)
# Out:
# 308

# %% [markdown]
# ## Save The PLIFs

# %%
plifs_pkl_path = DATA_DIR / f"plifs_multimers{settings.prepared_files_suffix}.pkl"

# %%
# save
with open(plifs_pkl_path, "wb") as f:
    pkl.dump(plif_dict, f)

# %%
# reload
with open(plifs_pkl_path, "rb") as f:
    plif_dict = pkl.load(f)
# Out:
# /Users/cbouysset/miniforge3/envs/plif-recovery/lib/python3.11/site-packages/prolif/interactions/base.py:42: UserWarning: The 'HBDonor' interaction has been superseded by a new class with id 0x7fecf8007540
#   warnings.warn(
# /Users/cbouysset/miniforge3/envs/plif-recovery/lib/python3.11/site-packages/prolif/interactions/base.py:42: UserWarning: The 'XBDonor' interaction has been superseded by a new class with id 0x7fed089ffa70
#   warnings.warn(
# /Users/cbouysset/miniforge3/envs/plif-recovery/lib/python3.11/site-packages/prolif/interactions/base.py:42: UserWarning: The 'Anionic' interaction has been superseded by a new class with id 0x7fecf8007f00
#   warnings.warn(
# /Users/cbouysset/miniforge3/envs/plif-recovery/lib/python3.11/site-packages/prolif/interactions/base.py:42: UserWarning: The 'PiCation' interaction has been superseded by a new class with id 0x7fecf8008890
#   warnings.warn(
# /Users/cbouysset/miniforge3/envs/plif-recovery/lib/python3.11/site-packages/prolif/interactions/base.py:42: UserWarning: The 'MetalAcceptor' interaction has been superseded by a new class with id 0x7fecf8104400
#   warnings.warn(

# %% [markdown]
# ## Calculate recovery

# %%
results = defaultdict(dict)
methods_pbar = tqdm(
    [
        "fred",
        "hybrid",
        "gold",
        "umol",
        "diffdock",
        "rfaa",
    ],
    position=0
)
targets_pbar = tqdm(position=1, leave=True)

for method in methods_pbar:
    targets_pbar.reset()
    targets_pbar.total = len(plif_dict[method])
    for target, other_fp in plif_dict[method].items():
        try:
            xtal_fp = plif_dict["xtal"][target]
        except KeyError:
            targets_pbar.update()
            continue
        xtal_file_prep = get_files(target, "xtal")
        other_file_prep = get_files(target, method)
        r = get_plif_recovery_rates(
            xtal_file_prep,
            other_file_prep,
            xtal_fp,
            other_fp,
        )
        results[method][target] = r
        targets_pbar.update()
targets_pbar.n = targets_pbar.total
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
plifs_recovery_pkl_path = (
    DATA_DIR / f"plifs_multimers_recovery{settings.prepared_files_suffix}.pkl"
)

# %%
# save
with open(plifs_recovery_pkl_path, "wb") as f:
    pkl.dump(results, f)

# %%
# reload
with open(plifs_recovery_pkl_path, "rb") as f:
    results = pkl.load(f)

# %% [markdown]
# ## Analysis and filtering

# %%
df = pd.DataFrame(
    [
        {
            "method": method,
            "target": target,
            "count_recovery": r.count_recovery,
            "reference_plifs": r.xtal_plif,
            "plifs": r.plif
        }
        for method, targets in results.items()
        for target, r in targets.items()
    ]
)
df.set_index(["method", "target"], inplace=True)
df
# Out:
#                    count_recovery  \
# method   target
# fred     5SAK_ZRY        0.250000
#          5SB2_1K2        0.750000
#          5SD5_HWI        0.500000
#          5SIS_JSM        0.333333
#          6M2B_EZO        1.000000
# ...                           ...
# rfaa     7PT3_3KK        0.000000
#          7TB0_UD1        0.181818
#          7V3S_5I9        0.200000
#          8EAB_VN2        0.200000
#          8F8E_XJI        0.285714
#
#                                                      reference_plifs  \
# method   target
# fred     5SAK_ZRY  D35.Z_HBDonor=1/D219.Z_HBDonor=1/T222.Z_HBDonor=2
#          5SB2_1K2  M97.Z_XBDonor=1/M102.Z_HBAcceptor=1/M102.Z_HBD...
#          5SD5_HWI  I7.Z_HBDonor=1/D29.Z_HBDonor=1/F33.Z_PiStackin...
#          5SIS_JSM  Y235.Z_HBAcceptor=1/Q268.Z_HBAcceptor=1/F271.Z...
#          6M2B_EZO                M12.Z_XBDonor=1/R105.Z_HBAcceptor=3
# ...                                                              ...
# rfaa     7PT3_3KK  Q241.Z_HBAcceptor=1/G256.Z_HBDonor=1/R259.Z_HB...
#          7TB0_UD1  N23.Z_HBAcceptor=1/R124.Z_HBAcceptor=1/D127.Z_...
#          7V3S_5I9  K82.Z_HBAcceptor=1/F106.Z_PiStacking=1/M132.Z_...
#          8EAB_VN2  F21.Z_PiStacking=1/L56.Z_HBDonor=1/K58.Z_HBAcc...
#          8F8E_XJI  H61.Z_HBAcceptor=1/H61.Z_PiStacking=1/R146.Z_X...
#
#                                                                plifs
# method   target
# fred     5SAK_ZRY  D35.Z_HBDonor=1/Y79.Z_PiStacking=1/Y226.Z_PiSt...
#          5SB2_1K2  M102.Z_HBAcceptor=1/M102.Z_HBDonor=1/D182.Z_HB...
#          5SD5_HWI  I7.Z_HBDonor=1/D29.Z_HBDonor=1/F33.Z_PiStackin...
#          5SIS_JSM                                Y235.Z_HBAcceptor=1
#          6M2B_EZO                M12.Z_XBDonor=1/R105.Z_HBAcceptor=3
# ...                                                              ...
# rfaa     7PT3_3KK  R244.Z_HBAcceptor=1/R411.Z_HBAcceptor=1/D414.Z...
#          7TB0_UD1  N443.B_HBAcceptor=1/E747.B_HBDonor=1/F750.B_Pi...
#          7V3S_5I9  K82.Z_PiCation=1/M132.Z_HBAcceptor=1/M132.Z_HB...
#          8EAB_VN2             F21.Z_PiStacking=1/I138.Z_HBAcceptor=1
#          8F8E_XJI  R513.B_PiCation=2/H61.Z_HBAcceptor=1/R219.Z_Pi...
#
# [1800 rows x 3 columns]

# %%
df.to_pickle(DATA_DIR / f"plifs_recovery_df{settings.prepared_files_suffix}.pkl")
df.reset_index().to_csv(
    DATA_DIR / f"plifs_recovery{settings.prepared_files_suffix}.csv", index=False
)

# %%
df = pd.read_pickle(DATA_DIR / f"plifs_recovery_df{settings.prepared_files_suffix}.pkl")
df
# Out:
#                    count_recovery  \
# method   target
# fred     5SAK_ZRY        0.250000
#          5SB2_1K2        0.750000
#          5SD5_HWI        0.500000
#          5SIS_JSM        0.333333
#          6M2B_EZO        1.000000
# ...                           ...
# rfaa     7PT3_3KK        0.000000
#          7TB0_UD1        0.181818
#          7V3S_5I9        0.200000
#          8EAB_VN2        0.200000
#          8F8E_XJI        0.285714
#
#                                                      reference_plifs  \
# method   target
# fred     5SAK_ZRY  D35.Z_HBDonor=1/D219.Z_HBDonor=1/T222.Z_HBDonor=2
#          5SB2_1K2  M97.Z_XBDonor=1/M102.Z_HBAcceptor=1/M102.Z_HBD...
#          5SD5_HWI  I7.Z_HBDonor=1/D29.Z_HBDonor=1/F33.Z_PiStackin...
#          5SIS_JSM  Y235.Z_HBAcceptor=1/Q268.Z_HBAcceptor=1/F271.Z...
#          6M2B_EZO                M12.Z_XBDonor=1/R105.Z_HBAcceptor=3
# ...                                                              ...
# rfaa     7PT3_3KK  Q241.Z_HBAcceptor=1/G256.Z_HBDonor=1/R259.Z_HB...
#          7TB0_UD1  N23.Z_HBAcceptor=1/R124.Z_HBAcceptor=1/D127.Z_...
#          7V3S_5I9  K82.Z_HBAcceptor=1/F106.Z_PiStacking=1/M132.Z_...
#          8EAB_VN2  F21.Z_PiStacking=1/L56.Z_HBDonor=1/K58.Z_HBAcc...
#          8F8E_XJI  H61.Z_HBAcceptor=1/H61.Z_PiStacking=1/R146.Z_X...
#
#                                                                plifs
# method   target
# fred     5SAK_ZRY  D35.Z_HBDonor=1/Y79.Z_PiStacking=1/Y226.Z_PiSt...
#          5SB2_1K2  M102.Z_HBAcceptor=1/M102.Z_HBDonor=1/D182.Z_HB...
#          5SD5_HWI  I7.Z_HBDonor=1/D29.Z_HBDonor=1/F33.Z_PiStackin...
#          5SIS_JSM                                Y235.Z_HBAcceptor=1
#          6M2B_EZO                M12.Z_XBDonor=1/R105.Z_HBAcceptor=3
# ...                                                              ...
# rfaa     7PT3_3KK  R244.Z_HBAcceptor=1/R411.Z_HBAcceptor=1/D414.Z...
#          7TB0_UD1  N443.B_HBAcceptor=1/E747.B_HBDonor=1/F750.B_Pi...
#          7V3S_5I9  K82.Z_PiCation=1/M132.Z_HBAcceptor=1/M132.Z_HB...
#          8EAB_VN2             F21.Z_PiStacking=1/I138.Z_HBAcceptor=1
#          8F8E_XJI  R513.B_PiCation=2/H61.Z_HBAcceptor=1/R219.Z_Pi...
#
# [1800 rows x 3 columns]

# %%
# only keep targets that are available in all methods
print("Initial number of targets:", df.index.get_level_values("target").nunique())
discard = set().union(*missing.values())
# exclude xtal structures without any interaction
no_xtal = df[df["count_recovery"].isna()].index.get_level_values("target").unique()
discard.update(no_xtal)
print(f"Dropping {len(no_xtal)} targets without interactions in reference")
print(f"Dropping {len(discard) - len(no_xtal)} targets missing one or more results: {*discard,}")
df = df[~df.index.get_level_values("target").isin(discard)]
print("Final number of targets:", df.index.get_level_values("target").nunique())
df
# Out:
# Initial number of targets: 306
# Dropping 7 targets without interactions in reference
# Dropping 45 targets missing one or more results: ('7MWN_WI5', '7P5T_5YG', '7NXO_UU8', '5SAK_ZRY', '8D5D_5DK', '7Z2O_IAJ', '7FRX_O88', '7MFP_Z7P', '7OP9_06K', '8EYE_X4I', '7WJB_BGC', '7P2I_MFU', '7K0V_VQP', '7XRL_FWK', '6Z14_Q4Z', '8G0V_YHT', '7OZ9_NGK', '7KC5_BJZ', '7QHG_T3B', '8F4J_PHO', '7DKT_GLF', '7TH4_FFO', '7P4C_5OV', '7AFX_R9K', '7B2C_TP7', '7M31_TDR', '6YRV_PJ8', '8EXL_799', '7CNQ_G8X', '7BJJ_TVW', '8AQL_PLG', '7Q5I_I0F', '7D5C_GV6', '7LOE_Y84', '7R6J_2I7', '7KB1_WBJ', '7QFM_AY3', '6XHT_V2V', '7BKA_4JC', '7WQQ_5Z6', '7PIH_7QW', '7NU0_DCL', '7X5N_5M5', '7QHL_D5P', '7SCW_GSP', '7UYB_OK0', '7D6O_MTE', '7ZDY_6MJ', '7SUC_COM', '7TB0_UD1', '7WDT_NGS', '7SFO_98L')
# Final number of targets: 256
#                    count_recovery  \
# method   target
# fred     5SB2_1K2        0.750000
#          5SD5_HWI        0.500000
#          5SIS_JSM        0.333333
#          6M2B_EZO        1.000000
#          6M73_FNR        0.500000
# ...                           ...
# rfaa     7OFF_VCB        0.000000
#          7PT3_3KK        0.000000
#          7V3S_5I9        0.200000
#          8EAB_VN2        0.200000
#          8F8E_XJI        0.285714
#
#                                                      reference_plifs  \
# method   target
# fred     5SB2_1K2  M97.Z_XBDonor=1/M102.Z_HBAcceptor=1/M102.Z_HBD...
#          5SD5_HWI  I7.Z_HBDonor=1/D29.Z_HBDonor=1/F33.Z_PiStackin...
#          5SIS_JSM  Y235.Z_HBAcceptor=1/Q268.Z_HBAcceptor=1/F271.Z...
#          6M2B_EZO                M12.Z_XBDonor=1/R105.Z_HBAcceptor=3
#          6M73_FNR  P87.Z_HBDonor=1/S116.Z_HBAcceptor=1/Q139.Z_HBD...
# ...                                                              ...
# rfaa     7OFF_VCB  ARG415.A_PiCation=1/ARG483.A_HBAcceptor=2/SER5...
#          7PT3_3KK  Q241.Z_HBAcceptor=1/G256.Z_HBDonor=1/R259.Z_HB...
#          7V3S_5I9  K82.Z_HBAcceptor=1/F106.Z_PiStacking=1/M132.Z_...
#          8EAB_VN2  F21.Z_PiStacking=1/L56.Z_HBDonor=1/K58.Z_HBAcc...
#          8F8E_XJI  H61.Z_HBAcceptor=1/H61.Z_PiStacking=1/R146.Z_X...
#
#                                                                plifs
# method   target
# fred     5SB2_1K2  M102.Z_HBAcceptor=1/M102.Z_HBDonor=1/D182.Z_HB...
#          5SD5_HWI  I7.Z_HBDonor=1/D29.Z_HBDonor=1/F33.Z_PiStackin...
#          5SIS_JSM                                Y235.Z_HBAcceptor=1
#          6M2B_EZO                M12.Z_XBDonor=1/R105.Z_HBAcceptor=3
#          6M73_FNR  P87.Z_HBDonor=1/A89.Z_HBDonor=1/S116.Z_HBAccep...
# ...                                                              ...
# rfaa     7OFF_VCB
#          7PT3_3KK  R244.Z_HBAcceptor=1/R411.Z_HBAcceptor=1/D414.Z...
#          7V3S_5I9  K82.Z_PiCation=1/M132.Z_HBAcceptor=1/M132.Z_HB...
#          8EAB_VN2             F21.Z_PiStacking=1/I138.Z_HBAcceptor=1
#          8F8E_XJI  R513.B_PiCation=2/H61.Z_HBAcceptor=1/R219.Z_Pi...
#
# [1517 rows x 3 columns]

# %%
df.reset_index().to_csv(
    DATA_DIR / f"plifs_recovery{settings.prepared_files_suffix}_filtered.csv",
    index=False,
)
